# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephTee/ml_unspervised_learning_algorithm_journey/blob/main/diabetes_training_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1
# In a dataset of "Used Car Sales," if we want to predict the Price, is "Mileage" an X feature or a y target?
#
# # Answer
# X feature

# %% [markdown]
# # Question 2
# Why do we split our data into Training and Testing sets? Why not train on 100% of the
# data?
#
# # Answer
# We split our data so that we can check with the test data if our model has learnt what we want them to learn.

# %% [markdown]
# # Coding Challenge Question 3
# 1. Load the Diabetes Dataset (built-in to sklearn) or any simple CSV you can find online.
# 2. Pick one feature (column) to predict the target.
# 3. Train a Linear Regression model.
# 4. Make a prediction for a specific value.
# 5. Bonus: Research how to use model.score(X, y) to measure the accuracy of your model.

# %%
from google.colab import drive
drive.mount('/content/drive')
print("Upload completed")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Upload completed

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression as LR
from sklearn.linear_model import LogisticRegression as LogReg
from sklearn.preprocessing import StandardScaler as SS
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# Loading CSV file into a pandas DataFrame
file_path = '/content/drive/MyDrive/machine_learning/diabetes_dataset.csv'
df = pd.read_csv(file_path)
print(f"Successfully loaded '{file_path}")
print(df.head())
print(df.tail())
print(df.shape)
# Out:
# Successfully loaded '/content/drive/MyDrive/machine_learning/diabetes_dataset.csv
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]
#      Pregnancies  Glucose  ...  Age  Outcome
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [5 rows x 9 columns]
# (768, 9)

# %%
# Getting some statistical measurement of the diabetes dataset
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
# Picking one feature to predict the target.
X = df[['BMI']]
y = df['Outcome']

# %%
# Splitting data into Training and Testing
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=33
)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (614, 1)
# X_test shape: (154, 1)
# y_train shape: (614,)
# y_test shape: (154,)

# %%
# Training a Linear Regression Model
model = LR()
model.fit(X_train, y_train)

print("Slope:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Slope: [0.01827046]
# Intercept: -0.2364161554183269

# %%
# Making Prediction

value = np.array([[40]])
prediction = model.predict(value)
print(f" The prdiction is {prediction[0]}")
# Out:
#  The prdiction is 0.49440232202791184
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Model Accuracy
r2 = model.score(X_test, y_test)
print("R-squared:", r2)
# Out:
# R-squared: 0.03949151612961399
